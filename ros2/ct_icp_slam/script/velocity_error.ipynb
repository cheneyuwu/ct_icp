# %%
import numpy as np
import numpy.linalg as npla
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib widget
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Times"],
    'font.size': 14,
})

np.set_printoptions(6, suppress=True)


def add_plot(ax, filename, label=None):
    error = np.loadtxt(filename)
    timestamps = error[:, 1] / 1e9
    w_mr_inr = error[:, 2:]  # n by 6
    ax[0, 0].plot(timestamps, w_mr_inr[:, 0], label=label)
    ax[1, 0].plot(timestamps, w_mr_inr[:, 1], label=label)
    ax[2, 0].plot(timestamps, w_mr_inr[:, 2], label=label)
    ax[0, 1].plot(timestamps, w_mr_inr[:, 3+0], label=label)
    ax[1, 1].plot(timestamps, w_mr_inr[:, 3+1], label=label)
    ax[2, 1].plot(timestamps, w_mr_inr[:, 3+2], label=label)

def add_legend(ax, prefix = "velocity"):
    legend = [['x [m/s]', 'y [m/s]', 'z [m/s]'], ['roll [rad/s]', 'pitch [rad/s]', 'yaw [rad/s]']]
    for i in range(3):
        for j in range(2):
            ax[i, j].set_xlabel('time [s]')
            ax[i, j].set_ylabel(prefix + ' ' + legend[j][i])
            ax[i, j].legend()

# %%
fig, ax = plt.subplots(3, 2, figsize=(16, 12))
# add_plot(ax, '/ext0/ASRL/temp/doppler_odometry_obelisk/kitti_360/steam_0710/velocity.txt', 'steam-p2p (new)')

# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/elastic_temp/velocity.txt', 'elastic-p2p')

# see what happens when adding more states
# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/steam_2states/velocity.txt', 'steam-p2p (2 states)')
# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/steam_10states/velocity.txt', 'steam-p2p (10 states)')
# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/steam_50states/velocity.txt', 'steam-p2p (50 states)')

#
# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/steam_0711_2states_no_interp/velocity.txt', 'steam-p2p (no interp)')
# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/steam_0711_2states/velocity.txt', 'steam-p2p (2 states)')
add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/steam_0711_50states/velocity.txt', 'steam-p2p (50 states)')

# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/spline_0.2_plot_2states/velocity.txt', 'spline (interp 2)')
add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/spline_0.2_window/velocity.txt', 'spline (0.2, l2, window)')
# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/spline/velocity.txt', 'spline (0.2, gm, window)')

add_legend(ax)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots(3, 2, figsize=(16, 12))
# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/steam_2states/pose.txt', 'steam-p2p (2)')
# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/steam_10states/pose.txt', 'steam-p2p (10)')
# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/steam_50states/pose.txt', 'steam-p2p (50)')
# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/steam_temp/pose.txt', 'steam-p2p (new)')
# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/steam_0711_no_interp/pose.txt', 'steam-p2p (no interp)')
# add_plot(ax, '/home/yuchen/ASRL/temp/doppler_odometry/boreas/aeva/steam_0711_interp/pose.txt', 'steam-p2p (interp)')
add_legend(ax, 'pose')
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
